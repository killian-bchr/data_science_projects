# %% [markdown]
# # **Database Creation for the Spotify Project**
#
# ## **Objective**
# This notebook describes the process used to create a dedicated database for this project.
#
# ## **Database Overview**
# The database is built using **SQLite** and is designed to store historical listening data and curated playlists for a recommendation algorithm.
#
# ### **Database Details**
# - **Name:** `spotify_project`
# - **Tables:**
#   - `tracks_history` : Stores all historically listened tracks. This table will be used to adapt the recommendation algorithm based on my listening history and preferences.
#   - **Curated Playlists for Recommendations:**
#     - `playlist_rap_us`
#     - `playlist_house`
#     - `playlist_drill`
#     - `playlist_80s`
#     - `playlist_afrobeat`
#
# These playlists will serve as a reference to improve the recommendation algorithm and tailor suggestions to my musical tastes.

# %%
# Import libraries and define global variables
import os
import spotify
import sqlite3
import pandas as pd
# %load_ext autoreload
# %autoreload 2

DB_name = 'spotify_project.db'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# To have a look to a specific table
def view_table(table_name='tracks_history', db_name=DB_name):
    conn = sqlite3.connect(db_name)
    df = pd.read_sql(f"SELECT * FROM {table_name}", conn)
    conn.close()
    return df

# %%
view_table(table_name='playlist_drill')
# Out:
#                   album_id                                         album_name  \
# 0   208okgvV6yEx0Aq9t8zT4p                                          Polémique
# 1   1hRmY5K4OzG8Wdxmn6YNlg                                         669, Pt. 2
# 2   0FEXxdB1W49qvYwKL0wnJh                                                669
# 3   34cYXBHmeJ49Tr4Y3plD9H                                  Ashe Tape, Vol. 3
# 4   7zrUnXByeOKHbXY3fyn6vz                                                LMF
# ..                     ...                                                ...
# 95  4I8edkU7TNJmSv4cpWjfSC                                          140 BPM 2
# 96  31H0KWvM2hCC3p8jkctCWN                                           DRILL FR
# 97  7IRchhaQTK6BFQAPkcPcHm  1PLIKÉ140 x Fumez The Engineer - Plugged In Fr...
# 98  1tTWT8dn8Iyh3BBVsltJBg                                      1PLIKTOI BIEN
# 99  2qnqLPZv38nQLPZbeSOL4T                                  Pas de ralentir 2
#
#            release_date                                album_artists_id  \
# 0   2021-05-15 00:00:00                          7GWvguZN6WpXDVaMDjg97v
# 1   2021-05-16 00:00:00                          4FjcWWBsbgD3TAEf2jQuVv
# 2   2018-09-20 00:00:00                          43mlbNLGRuLXwqTE8G61JB
# 3   2021-04-09 00:00:00                          3tTvSeZiFDP3CY5EdPGcR4
# 4   2020-09-11 00:00:00                          76Pl0epAMXVXJspaSuz8im
# ..                  ...                                             ...
# 95  2021-02-05 00:00:00                          5gs4Sm2WQUkcGeikMcVHbh
# 96  2021-02-26 00:00:00                          5gqmbbfjcikQBzPB5Hv13I
# 97  2020-10-15 00:00:00  0ksX396B3t2Gt8kwr0BJZk, 4Ue6MAZqz18NlaOQomRXLU
# 98  2020-05-28 00:00:00                          4Ue6MAZqz18NlaOQomRXLU
# 99  2021-09-07 00:00:00                          3mKyKC4BjNrNJSSBSrNy0a
#
#                album_artists_name  duration                track_id  \
# 0                      pauldscrga   176.427  5nLe4rNMf6B5v9sJ6gGCQO
# 1                             667   478.693  55rPRY6upmsnuCdJTW7UQt
# 2                         Lyonzon   305.600  3nSL8n2FdvP3nLycf3Ip93
# 3                         ASHE 22   227.040  02uSh14aUckmfTVj5MEhmg
# 4                 Freeze corleone   170.106  5IkofYa6Ac1plKIf6nYkDE
# ..                            ...       ...                     ...
# 95                          Hamza   253.906  1Ujvp85FTkDkCdJPPM21wI
# 96                           Gazo   205.253  10nCB4Iq9BI3aW2iEldiR9
# 97  Fumez The Engineer, 1PLIKÉ140   177.103  1eQXQNNSYGInObudf5yXbg
# 98                      1PLIKÉ140   140.434  7m1wsat0RhxlxviJhQ3sfJ
# 99                            Mig   339.903  0PzDWcc52BCrz6z1Z6CnuU
#
#                                            track_name  popularity  \
# 0                                           Polémique           0
# 1                                          669, Pt. 2          37
# 2                                                 669          25
# 3                                      Scellé Part. 3           0
# 4                                       Scellé part.2          45
# ..                                                ...         ...
# 95                Spaghetti (feat. Gazo & Guy2Bezbar)           0
# 96                                               A$AP          45
# 97  1PLIKÉ140 x Fumez The Engineer - Plugged In Fr...          34
# 98                                      1PLIKTOI BIEN          49
# 99                                  Pas de ralentir 2          35
#
#                                      track_artists_id  \
# 0      7GWvguZN6WpXDVaMDjg97v, 5OVwoZ9WDfQiyUkblkOGLe
# 1      4FjcWWBsbgD3TAEf2jQuVv, 43mlbNLGRuLXwqTE8G61JB
# 2                              43mlbNLGRuLXwqTE8G61JB
# 3      3tTvSeZiFDP3CY5EdPGcR4, 76Pl0epAMXVXJspaSuz8im
# 4      76Pl0epAMXVXJspaSuz8im, 3tTvSeZiFDP3CY5EdPGcR4
# ..                                                ...
# 95  5gs4Sm2WQUkcGeikMcVHbh, 5gqmbbfjcikQBzPB5Hv13I...
# 96                             5gqmbbfjcikQBzPB5Hv13I
# 97     0ksX396B3t2Gt8kwr0BJZk, 4Ue6MAZqz18NlaOQomRXLU
# 98                             4Ue6MAZqz18NlaOQomRXLU
# 99                             3mKyKC4BjNrNJSSBSrNy0a
#
#                track_artists_name track_listeners track_playcount  \
# 0          pauldscrga, Freeze Cee            1519           11302
# 1                    667, Lyonzon            7704           88497
# 2                         Lyonzon            3132           25189
# 3        ASHE 22, Freeze corleone            6829           62105
# 4        Freeze corleone, ASHE 22           21604          273035
# ..                            ...             ...             ...
# 95        Hamza, Gazo, Guy2Bezbar            None            None
# 96                           Gazo            9705           92491
# 97  Fumez The Engineer, 1PLIKÉ140            3360           21173
# 98                      1PLIKÉ140            7048           63764
# 99                            Mig            2113           21985
#
#                                       similar_artists  \
# 0        667, Adekhey, XIII B, Mini RTTCLAN, Swey Zen
# 1      EniMa, Afro S, Sazamyzy, DOC OVG, Mini RTTCLAN
# 2
# 3   Freeze Corleone, Kaaris, Osirus Jack, Alpha Wa...
# 4   Freeze Corleone, Kaaris, Osirus Jack, Alpha Wa...
# ..                                                ...
# 95  Ninho, Tiakola, Damso, Leto, RSKO, Josman, Nis...
# 96              Tiakola, Leto, Niska, Koba LaD, Ninho
# 97        Beendo Z, Niska, menace Santana, Gazo, Ziak
# 98        Beendo Z, Niska, menace Santana, Gazo, Ziak
# 99  Skolim, Larry, Boys, Daj To Głośniej, Piękni i...
#
#                                            track_tags  \
# 0
# 1   Hip-Hop, french, hip hop, seen live, metal, ro...
# 2                 Hip-Hop, french, hip hop, trap, rap
# 3        Hip-Hop, french, lyonzon, drill, france, rap
# 4        Hip-Hop, french, lyonzon, drill, france, rap
# ..                                                ...
# 95  Hip-Hop, french, junk, belgian, House, Belgium...
# 96         Hip-Hop, french, drill, french rap, france
# 97  Hip-Hop, hip hop, numeric, drill, UK Drill, nu...
# 98                numeric, numbers, french rap, 92140
# 99  french, disco polo, electronic, trip hop, trip...
#
#                                             image_url  \
# 0   https://i.scdn.co/image/ab67616d00001e02e8af6a...
# 1   https://i.scdn.co/image/ab67616d00001e02dcc5c7...
# 2   https://i.scdn.co/image/ab67616d00001e02f927ab...
# 3   https://i.scdn.co/image/ab67616d00001e02ed1912...
# 4   https://i.scdn.co/image/ab67616d00001e0204a2bc...
# ..                                                ...
# 95  https://i.scdn.co/image/ab67616d00001e0267c883...
# 96  https://i.scdn.co/image/ab67616d00001e02f8e112...
# 97  https://i.scdn.co/image/ab67616d00001e02892bb9...
# 98  https://i.scdn.co/image/ab67616d00001e02076777...
# 99  https://i.scdn.co/image/ab67616d00001e023f12a3...
#
#                                           spotify_url
# 0   https://open.spotify.com/track/5nLe4rNMf6B5v9s...
# 1   https://open.spotify.com/track/55rPRY6upmsnuCd...
# 2   https://open.spotify.com/track/3nSL8n2FdvP3nLy...
# 3   https://open.spotify.com/track/02uSh14aUckmfTV...
# 4   https://open.spotify.com/track/5IkofYa6Ac1plKI...
# ..                                                ...
# 95  https://open.spotify.com/track/1Ujvp85FTkDkCdJ...
# 96  https://open.spotify.com/track/10nCB4Iq9BI3aW2...
# 97  https://open.spotify.com/track/1eQXQNNSYGInObu...
# 98  https://open.spotify.com/track/7m1wsat0Rhxlxvi...
# 99  https://open.spotify.com/track/0PzDWcc52BCrz6z...
#
# [100 rows x 17 columns]

# %%
# Load a specific table to CSV file
def load_tracks_history_csv(table_name='tracks_history', db_name=DB_name):
    conn = sqlite3.connect(db_name)

    tracks_history_df = pd.read_sql(f"SELECT * FROM {table_name}", conn)

    if os.path.exists('track_history.csv'):
        tracks_history_df.to_csv('track_history.csv', index=False)
        print("File 'track_history.csv' has been replaced succesfully")

    else:
        tracks_history_df.to_csv('track_history.csv', index=False)
        print("File 'track_history.csv' has been created successfully")

    conn.close()

# %%
load_tracks_history_csv()
# Out:
# File 'track_history.csv' has been created successfully

# %%
# Import playlists ids
playlist_drill = '1z1tOO60TXJaLEfXb5Z1pw'
playlist_house = '1vIMNWoiysQgw4q13PErN4'
playlist_rap_us = '4OZ02mQrmS1LU8bkG09vq7'
playlist_afrobeat = '25Y75ozl2aI0NylFToefO5'
playlist_annees_80 = '0slE73JFtRr3F2KnfoWlbO'

playlist_ids = {'playlist_drill':playlist_drill, 'playlist_house':playlist_house, 'playlist_rap_us':playlist_rap_us,
                'playlist_afrobeat':playlist_afrobeat, 'playlist_annees_80':playlist_annees_80}

# %%
def create_playlist_tables(playlist_ids, DB_name="spotify_project.db"):
    conn = sqlite3.connect(DB_name)

    for playlist_name, playlist_id in playlist_ids.items():
        # Récupérer les morceaux de la playlist
        new_tracks_df = spotify.get_playlist_tracks(playlist_id)

        # Vérifier si la table existe déjà dans la base de données
        query = f"SELECT name FROM sqlite_master WHERE type='table' AND name='{playlist_name}';"
        table_exists = pd.read_sql(query, conn)

        if table_exists.empty:
            # Si la table n'existe pas, la créer et ajouter tous les morceaux
            new_tracks_df.to_sql(playlist_name, conn, if_exists="replace", index=False)
            print(f"Table {playlist_name} created and {len(new_tracks_df)} tracks added.")
        else:
            # Si la table existe, récupérer les morceaux déjà stockés
            existing_tracks_query = f"SELECT track_id FROM {playlist_name}"
            try:
                existing_tracks_df = pd.read_sql(existing_tracks_query, conn)
            except:
                existing_tracks_df = None

            # Filtrer les nouveaux morceaux qui ne sont pas déjà en base
            if existing_tracks_df is not None and not existing_tracks_df.empty:
                new_tracks_df = new_tracks_df[~new_tracks_df['track_id'].isin(existing_tracks_df['track_id'])]

            # Ajouter uniquement les nouveaux morceaux
            if not new_tracks_df.empty:
                new_tracks_df.to_sql(playlist_name, conn, if_exists="append", index=False)
                print(f"{len(new_tracks_df)} new tracks added to {playlist_name}.")
            else:
                print(f"No new tracks to add for {playlist_name}.")

    conn.close()

# %%
create_playlist_tables(playlist_ids)
# Out:
# No new tracks to add for playlist_drill.
# No new tracks to add for playlist_house.
# No new tracks to add for playlist_rap_us.
# No new tracks to add for playlist_afrobeat.
# No new tracks to add for playlist_annees_80.
